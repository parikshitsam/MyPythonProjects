# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# import seaborn as sns
import statsmodels.api as sm

df1 = pd.read_csv('6_4.txt', sep = ' ', header=0, index_col=0, usecols= [0,1,2,3,4])
df2 = pd.read_csv('6_4.txt', sep = ' ', header=0, index_col=0, usecols= [5,6,7,8,9])
#df = df1.append(df2)
df2.head()
# Out:
#                CM.1  FLFP.1  PGNP.1  TFR.1
# Observation.1
# 33              142      50    8640   7.17
# 34              104      62     350   6.60
# 35              287      31     230   7.00
# 36               41      66    1620   3.91
# 37              312      11     190   6.70

# %%
df2.columns = list(df1.columns)
df = df1.append(df2)
df
# Out:
#      CM  FLFP  PGNP   TFR
# 1   128    37  1870  6.66
# 2   204    22   130  6.15
# 3   202    16   310  7.00
# 4   197    65   570  6.25
# 5    96    76  2050  3.81
# ..  ...   ...   ...   ...
# 60  115    62  1470  3.89
# 61  186    45   300  6.90
# 62   47    85  3630  4.10
# 63  178    45   220  6.09
# 64  142    67   560  7.20
#
# [64 rows x 4 columns]

# %%
pg_fl= df.loc[:,['PGNP','FLFP']]
cm = df.loc[:,'CM']
pg_fl = sm.add_constant(pg_fl)
model = sm.OLS(cm,pg_fl).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     CM   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     73.83
# Date:                Thu, 09 Jul 2020   Prob (F-statistic):           5.12e-17
# Time:                        10:01:04   Log-Likelihood:                -328.10
# No. Observations:                  64   AIC:                             662.2
# Df Residuals:                      61   BIC:                             668.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        263.6416     11.593     22.741      0.000     240.460     286.824
# ...

# %%
from scipy.stats import f

# %%
"{:.100f}".format(f.sf(112,1,62))
# Out:
# '0.0000000000000015962218762668622856516372744691578043078254798420312354778616281691938638687133789062'

# %%
f = model.f_test('(PGNP = FLFP)')
'{:.2f}'.format(f.pvalue)
# Out:
# '0.00'
