# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
fig2 = plt.figure()
ax2 = fig2.add_axes([0.15,0.1,0.7,0.3])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax = fig.add_subplot(2,1,1)
t = np.arange(0,1,0.01)
s = np.sin(2*np.pi*t)
line, =ax.plot(t,s,c='blue',lw=2)
line2 = ax.plot(t,np.zeros(100,),'r--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
del ax.lines[1]
